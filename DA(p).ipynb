# %% [markdown]
# <a href="https://colab.research.google.com/github/jvnsaithilak/Data_analytics_training/blob/main/DA(p).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

subjects = ['Python', 'Java', 'C++', 'SQL']
marks = [85, 78, 90, 70]

plt.bar(subjects, marks)
plt.title("Student Marks")
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt

days = [1,2,3,4,5]
sales = [100,150,120,180,200]

plt.plot(days, sales, marker='o')
plt.title("Daily Sales")
plt.xlabel("Days")
plt.ylabel("Sales")
plt.show()

# %%
import matplotlib.pyplot as plt

labels = ['Python', 'Java', 'C++', 'SQL']
sizes = [40, 30, 20, 10]

plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title("Programming Language Usage")
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [2,3,5,2,9]

plt.scatter(x, y)
plt.title("Scatter Plot Example")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.show()

# %%
import matplotlib.pyplot as plt

marks = [55,60,65,70,75,80,85,90,95]

plt.hist(marks, bins=5)
plt.title("Marks Distribution")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()
